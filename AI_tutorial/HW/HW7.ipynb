# %% [markdown]
# # Homework 7 Guide

# %% [markdown]
# 1. Save a copy of this `.ipynb` file to your Google Drive or PC.
# 2. Rename the file from **`HW7.ipynb`** to **`HW7_(your name).ipynb`**.
# 3. Complete the code cells below by following the given instructions.
# 4. Save your work and upload the `.ipynb` file to Canvas.
#    - Do **NOT** clear the outputs; leave your results visible.
# 5. ⚠️ **IMPORTANT**: Convert your `.ipynb` file to a `.PDF` and upload them **together**.
#     - Go to the top menu → **File → Print → Save as PDF**.

# %% [markdown]
# .
#
# .

# %% [markdown]
# # [HW 7] Grid Search for Autoencoder (AE) Hyperparameters
#
# 1. Load the `FeatureSelected.csv` file stored in your Google Drive (the result from **DA3-2**).
#
# 2. Prepare the **Training**, **Validation**, and **Test** datasets for unsupervised learning, following the same process as in **ML3-1**.
#
# 3. Perform a **grid search** over the following Autoencoder hyperparameters:
#    - **Activation:** `['relu', 'tanh']`
#    - **Bottleneck layer size:** `[3, 5, 7]`
#    > ⚠️ Note: Refer to **ML3-2**, but use **`val_loss`** as the model performance metric instead of `accuracy`.
#
# 4. Select the **best AE model** (the one with the lowest `val_loss`) and print:
#    - The activation function used
#    - The bottleneck layer dimension
#    - The corresponding validation loss (`val_loss`)
#
# 5. Using the **best AE model**, determine the **threshold** for fault detection based on the **ROC (Receiver Operating Characteristic) curve** as done in **ML3-1**.
#    (The 3-sigma threshold method can be omitted for this task.)
#
# 6. Based on the selected threshold, evaluate the model on the **Test data** and print the final **fault detection results**:
#    - **Confusion matrix**
#    - Four evaluation metrics: **Accuracy, Precision, Recall,** and **F1-Score**.

# %%
# Add cells if needed to show all results

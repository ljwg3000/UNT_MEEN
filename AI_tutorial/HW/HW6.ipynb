# %% [markdown]
# # Homework 6 Guide

# %% [markdown]
# 1. Save a copy of this `.ipynb` file to your Google Drive or PC.
# 2. Rename the file from **`HW6.ipynb`** to **`HW6_(your name).ipynb`**.
# 3. Complete the code cells below by following the given instructions.
# 4. Save your work and upload the `.ipynb` file to Canvas.
#    - Do **NOT** clear the outputs; leave your results visible.
# 5. ⚠️ **IMPORTANT**: Convert your `.ipynb` file to a `.PDF` and upload them **together**.
#     - Go to the top menu → **File → Print → Save as PDF**.

# %% [markdown]
# .
#
# .

# %% [markdown]
# # [HW 6] Multi-class Classification using CNN
#
# 1. Load the 3-class dataset as done in **ML2_Code2**.
# 2. For each data sample, extract only the **voltage signal** and create the array `VolData` (refer to **ML2_Code1**).
# 3. Convert the extracted `VolData` array into a spectrogram dataset `VolSTFT` using **STFT** (refer to **ML2_Code1**).
# 4. Split `VolSTFT` into `NormalSet`, `AbnormalSet_1`, and `AbnormalSet_2`. Then reshape each to have a channel dimension, resulting in the shape `(40, 40, 1)` (refer to **ML2_Code1**).
# 5. Prepare the training and testing datasets along with the **3-class labels**.
# 6. Build and train a **CNN model** for 3-class classification.
#    - You may freely modify the CNN architecture based on what was practiced in the lab.
# 7. Save the model and plot the training history graphs.
# 8. Evaluate the model on the test data by calculating and printing the **confusion matrix** and the four evaluation metrics: **Accuracy, Precision, Recall, and F1-score**.

# %%
# Add cells if needed to show all results

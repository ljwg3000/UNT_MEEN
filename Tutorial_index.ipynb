# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunseob/purdue_me597/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table><tr>
#     <td  style="background-color:#ffffff;text-align:left;"><a href="http://www.purdue.edu" target="_blank"><img src="https://github.com/ljwg3000/UNT_MEEN/blob/main/img/unt-logo.png?raw=1" width="100%" align="left"></a></td>
#     <td style="background-color:#ffffff;">&nbsp;</td>
#     <td style="background-color:#ffffff;vertical-align:text-middle;text-align:right;">
#         <table><tr style="background-color:white;">
#             <td><h1 style="font-size:5vw">MEEN4800+5800 - Artificial Intelligence in Mechanical Engineering</h1></td>
#             <td>
#         </tr></table>
#     </td>
# </tr></table>

# %% [markdown]
# ## Overview of AI Tutorial
#
# Through Artificial Intelligence (AI) tutorials, you will understand the concept and purpose of each techique of data analysis (DA) and machine learning (ML), and practice them using colab. The tutorials will be broken down into two main parts as followed.
#
# .
#
# ### **1. Data Analysis**
#
#   a. Data handling
#
#   b. Data indexing (numpy, pandas)
#
#   c. 2D graph plotting (matplotlib)
#
#   b. Signal processing (FFT, STFT, WT)
#
#   e. Feature extraction & selection (t-Test)
#
#   f. Data visualization (PCA, t-SNE)
#
#   g. Time series (conitunous) data segmentation
#
# .
#
# ### **2. Machine Learning / Deep Learning**
#
#   a. Basic Neural Network - Multi-Layer Perceptron (MLP)
#
#   b. Convolutional Neural Network (CNN) - Supervised Learning
#
#   c. Autoencoder (AE) - Unsupervised Learning
#
#   d. Long-Short Term Memory (LSTM) - Supervised Learning
#
#   e. Hyperparameter optimization (grid search)
#
#   f. Multi-class classification
#
#   g. Transfer learning (Layer freezing, Fine-tuning)

# %% [markdown]
# ## **Table of Content**
#
# ---
# ### **(Week 2): Data Analysis 1**
#
# [DA1-1: Exercise for data handling and plotting](AI_tutorial/Week2/DA1_Code1.ipynb)\
# DA1-2: TBA\
# DA1-3: TBA
#
# #### Homework 1
#
# TBA
#
# ---
# ### **(Week 3) Data Analysis 2**
#
# TBA
#
# ---
# ### **(Week 4) Data Analysis 3**
#
# TBA
#
# ---
# ### **(Week 5) Data Analysis 4**
#
# TBA
#
# ---
# ### **(Week 6) Machine Learning 1**
#
# TBA
#
# ---
# ### **(Week 7) Machine Learning 2**
#
# TBA
#
# ---
# ### **(Week 8) Machine Learning 3**
#
# TBA
#
# ---
# ### **(Week 9) Machine Learning 4**
#
# TBA
#
# ---
# ### **(Week 10) Midterm Data Challege**
#
# TBA
#
# ---
# ### **(Week 11) Advanced AI 1**
#
# TBA
#
# ---
# ### **(Week 12) Advanced AI 2**
#
# TBA
#
# ---
